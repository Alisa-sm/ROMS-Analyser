# %%
import pandas as pd
import numpy as np

# %%
emhp_data = pd.read_excel('EMHP.xlsx')
emhp_data
# Out:
#       patient_id completed_by         username     pat_age pat_gen  \
# 0         199355      patient         EI140819  year 10/11  female
# 1         202611      patient    India_21stNov  year 12/13  female
# 2         205569     parent_1       KB28022020         NaN     NaN
# 3         205926     parent_1  pod_user_205926         NaN     NaN
# 4         205111     parent_1  pod_user_205111         NaN     NaN
# ...          ...          ...              ...         ...     ...
# 1306      207278      patient            PLS20  year 12/13  female
# 1307      209780      patient  pod_user_209780         NaN     NaN
# 1308      208557      patient             pod2         NaN     NaN
# 1309      206862      patient          RowenaC    year 4/5    male
# 1310      209947      patient       swl_lbf_dc         NaN     NaN
#
#       project_unique_identifier  site_name  group_label  status_label  \
# 0                           NaN        NaN          NaN           NaN
# ...

# %%
filtered_emhp_data = emhp_data.drop(['username','pat_age','pat_gen','project_unique_identifier','site_name','group_label','status_label','esq_parent_date_t1','esq_parent_q1_t1','esq_parent_q2_t1','esq_parent_q3_t1','esq_parent_q4_t1','esq_parent_q5_t1','esq_parent_q6_t1','esq_parent_q7_t1','esq_parent_q8_t1','esq_parent_q9_t1','esq_parent_q10_t1','esq_parent_q11_t1','esq_parent_q12_t1','esq_parent_q13_t1','esq_parent_q14_t1','esq_parent_q15_t1','esq_parent_date_t2','esq_parent_q1_t2','esq_parent_q2_t2','esq_parent_q3_t2','esq_parent_q4_t2','esq_parent_q5_t2','esq_parent_q6_t2','esq_parent_q7_t2','esq_parent_q8_t2','esq_parent_q9_t2','esq_parent_q10_t2','esq_parent_q11_t2','esq_parent_q12_t2','esq_parent_q13_t2','esq_parent_q14_t2','esq_parent_q15_t2','esq_self_12_18_date_t1','esq_self_12_18_q1_t1','esq_self_12_18_q2_t1','esq_self_12_18_q3_t1','esq_self_12_18_q4_t1','esq_self_12_18_q5_t1','esq_self_12_18_q6_t1','esq_self_12_18_q7_t1','esq_self_12_18_q8_t1','esq_self_12_18_q9_t1','esq_self_12_18_q10_t1','esq_self_12_18_q11_t1','esq_self_12_18_q12_t1','esq_self_12_18_q13_t1','esq_self_12_18_q14_t1','esq_self_12_18_q15_t1','esq_self_12_18_date_t2','esq_self_12_18_q1_t2','esq_self_12_18_q2_t2','esq_self_12_18_q3_t2','esq_self_12_18_q4_t2','esq_self_12_18_q5_t2','esq_self_12_18_q6_t2','esq_self_12_18_q7_t2','esq_self_12_18_q8_t2','esq_self_12_18_q9_t2','esq_self_12_18_q10_t2','esq_self_12_18_q11_t2','esq_self_12_18_q12_t2','esq_self_12_18_q13_t2','esq_self_12_18_q14_t2','esq_self_12_18_q15_t2'
], axis = 1)
filtered_emhp_data
# Out:
#       patient_id rcads_subscale rcads_date_t1  rcads_score_mdd_t1  \
# 0         199355             SP    2019-08-14                10.0
# 1         202611             PD    2019-11-23                16.0
# 2         205569            NaN           NaT                 NaN
# 3         205926            NaN           NaT                 NaN
# 4         205111            NaN           NaT                 NaN
# ...          ...            ...           ...                 ...
# 1306      207278             SP    2020-05-14                 NaN
# 1307      209780            NaN           NaT                 NaN
# 1308      208557            NaN           NaT                 NaN
# 1309      206862            NaN           NaT                 NaN
# 1310      209947            NaN           NaT                 NaN
#
#       rcads_score_gad_t1  rcads_score_ocd_t1  rcads_score_pd_t1  \
# 0                    2.0                 0.0                3.0
# ...

# %%
filtered_emhp_data = filtered_emhp_data.drop([filtered_emhp_data.columns[119], filtered_emhp_data.columns[115], filtered_emhp_data.columns[113], filtered_emhp_data.columns[111]], axis = 'columns')
filtered_emhp_data
# Out:
#       patient_id rcads_subscale rcads_date_t1  rcads_score_mdd_t1  \
# 0         199355             SP    2019-08-14                10.0
# 1         202611             PD    2019-11-23                16.0
# 2         205569            NaN           NaT                 NaN
# 3         205926            NaN           NaT                 NaN
# 4         205111            NaN           NaT                 NaN
# ...          ...            ...           ...                 ...
# 1306      207278             SP    2020-05-14                 NaN
# 1307      209780            NaN           NaT                 NaN
# 1308      208557            NaN           NaT                 NaN
# 1309      206862            NaN           NaT                 NaN
# 1310      209947            NaN           NaT                 NaN
#
#       rcads_score_gad_t1  rcads_score_ocd_t1  rcads_score_pd_t1  \
# 0                    2.0                 0.0                3.0
# ...

# %%
filtered_emhp_data['goals_date_t1']
# Out:
# 0      2019-08-21
# 1      2019-12-05
# 2             NaT
# 3             NaT
# 4             NaT
#           ...
# 1306          NaT
# 1307          NaT
# 1308          NaT
# 1309          NaT
# 1310          NaT
# Name: goals_date_t1, Length: 1311, dtype: datetime64[ns]
